# %%
from Models.LinearRegression import MyLineReg

# %%
# Подключаем библиотеки
import math 
import pandas as pd
import numpy as np
from datetime import date
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from time import time
import holidays
from sklearn.metrics import mean_absolute_percentage_error
from google.oauth2 import service_account

# %%
#импортируем данные из BQ
pd.set_option ('display.max_columns', 599)
pd.set_option ('display.max_rows', 599)
from google.oauth2 import service_account
project_id = 'kolesa-android-app'
credentials = 'kolesa-android-app-715adc9bdf26.json'
credentials = service_account.Credentials.from_service_account_file(credentials)

# %%
q = "SELECT * FROM kolesa-android-app.academy.time_series_dataset ORDER BY 1"
data = pd.read_gbq(q, project_id=project_id, credentials=credentials, dialect='standard', progress_bar_type = 'tqdm')
data.head()
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
#    event_date      y
# 0  2020-01-01   5721
# 1  2020-01-02   8274
# 2  2020-01-03   9344
# 3  2020-01-04   9864
# 4  2020-01-05  10435

# %%
#импорт данных csv на случай отсутствия возможности подключения к BQ
#csv_file_path = "data/data.csv"
#data = pd.read_csv(csv_file_path)
#data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event_date  1096 non-null   dbdate
#  1   y           1096 non-null   Int64
# dtypes: Int64(1), dbdate(1)
# memory usage: 18.3 KB

# %%
#меняем названия столбцов и устанавливаем один из них в качестве временного индекса
data.columns = ['ds', 'y']
data.index = pd.to_datetime(data['ds'])
data.tail()
# Out:
#                     ds      y
# ds
# 2022-12-27  2022-12-27  17042
# 2022-12-28  2022-12-28  16195
# 2022-12-29  2022-12-29  14966
# 2022-12-30  2022-12-30  13070
# 2022-12-31  2022-12-31   9991

# %%
#удаляем повторяющиеся строки, если таковые имеются
data = data.drop_duplicates()
data.shape
# Out:
# (1094, 2)

# %%
#изучаем статистические показатели столбцов датафрейма
data.describe()
# Out:
#                    y
# count         1094.0
# mean    22656.698355
# std    301942.192404
# min             51.0
# 25%          11820.0
# 50%          13232.5
# 75%         15786.75
# max       10000000.0

# %%
#найдем максимальное значение для определения выброса
data[data['y'] == data['y'].max()]
# Out:
#                     ds         y
# ds
# 2022-07-05  2022-07-05  10000000

# %%
#производим очистку данных
data = data.drop(data[data['y'] > 1000000].index)
data = data.drop(data[data['y'] < 5000].index)

# %%
#изучаем статистические показатели столбцов датафрейма после очистки данных
data.shape
# Out:
# (1088, 2)

# %%
data.describe()
# Out:
#                   y
# count        1088.0
# mean   13582.417279
# std     2819.739204
# min          5721.0
# 25%         11881.5
# 50%         13242.5
# 75%        15787.25
# max         19805.0

# %%
#Отмечаем даты праздников и эпидемии
def ramadan(ds):
    date = pd.to_datetime(ds)
    return (date >= pd.to_datetime('2020-04-24') and date<= pd.to_datetime('2020-05-24')
           or date >= pd.to_datetime('2021-04-13') and date<= pd.to_datetime('2021-05-13')
           or date >= pd.to_datetime('2022-04-03') and date<= pd.to_datetime('2022-05-03')
           or date >= pd.to_datetime('2023-03-23') and date<= pd.to_datetime('2023-04-24'))
def corona(ds):
    date = pd.to_datetime(ds)
    return (date >= pd.to_datetime('2020-03-18') and date<= pd.to_datetime('2020-05-11'))
data['is_ramadan'] = data['ds'].apply(ramadan)
data['is_corona'] = data['ds'].apply(corona)
data['ramadan'] = data['is_ramadan'].apply(int)
data['corona'] = data['is_corona'].apply(int)
data.ds = pd.to_datetime(data['ds'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1088 entries, 2020-01-01 to 2022-12-31
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ds          1088 non-null   datetime64[ns]
#  1   y           1088 non-null   Int64
#  2   is_ramadan  1088 non-null   bool
#  3   is_corona   1088 non-null   bool
#  4   ramadan     1088 non-null   int64
#  5   corona      1088 non-null   int64
# dtypes: Int64(1), bool(2), datetime64[ns](1), int64(2)
# memory usage: 45.7 KB

# %%
data.drop('is_ramadan', axis=1, inplace=True)
data.drop('is_corona', axis=1, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1088 entries, 2020-01-01 to 2022-12-31
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ds       1088 non-null   datetime64[ns]
#  1   y        1088 non-null   Int64
#  2   ramadan  1088 non-null   int64
#  3   corona   1088 non-null   int64
# dtypes: Int64(1), datetime64[ns](1), int64(2)
# memory usage: 43.6 KB

# %%
data.head()
# Out:
#                    ds      y  ramadan  corona
# ds
# 2020-01-01 2020-01-01   5721        0       0
# 2020-01-02 2020-01-02   8274        0       0
# 2020-01-03 2020-01-03   9344        0       0
# 2020-01-04 2020-01-04   9864        0       0
# 2020-01-05 2020-01-05  10435        0       0

# %%
# Составляем датасет праздников

holidays_kz = holidays.KZ(years = (2020, 2021, 2022, 2023))
df_holidays = pd.DataFrame.from_dict(holidays_kz, orient = 'index').rename(columns = {0:'holiday'})
df_holidays['ds'] = df_holidays.index
df_holidays.reset_index(drop=True, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1088 entries, 2020-01-01 to 2022-12-31
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ds       1088 non-null   datetime64[ns]
#  1   y        1088 non-null   Int64
#  2   ramadan  1088 non-null   int64
#  3   corona   1088 non-null   int64
# dtypes: Int64(1), datetime64[ns](1), int64(2)
# memory usage: 43.6 KB

# %%
data.head()
# Out:
#                    ds      y  ramadan  corona
# ds
# 2020-01-01 2020-01-01   5721        0       0
# 2020-01-02 2020-01-02   8274        0       0
# 2020-01-03 2020-01-03   9344        0       0
# 2020-01-04 2020-01-04   9864        0       0
# 2020-01-05 2020-01-05  10435        0       0

# %%
#построим линейный график временного ряда
data.plot(x="ds",y="y",kind="line", figsize=(20, 10));

# %%
#создаем фичи в качестве новых столбцов таблицы
data['is_holiday'] = data['ds'].isin(df_holidays['ds'])
data['is_holiday'] = data['is_holiday'].apply(int)
reference_date = pd.Timestamp('2019-12-30')
data['years'] = (data['ds']).dt.year
data['months'] = (data['ds'] ).dt.month
data['days'] = (data['ds']).dt.day
data['dayoftheweek'] = (data['ds']).dt.dayofweek
data['days_since_years'] = np.log((data['ds']).dt.year - 2018)
data['days_since_months'] = np.log((data['ds'] ).dt.month+1)
data['days_since_days'] = np.log((data['ds'] - reference_date).dt.days)
data['days_since_dow'] = np.log((data['ds']).dt.dayofweek+1)
data.y = data.y.astype('int')
data
# Out:
#                    ds      y  ramadan  corona  is_holiday  years  months  \
# ds
# 2020-01-01 2020-01-01   5721        0       0           1   2020       1
# 2020-01-02 2020-01-02   8274        0       0           1   2020       1
# 2020-01-03 2020-01-03   9344        0       0           0   2020       1
# 2020-01-04 2020-01-04   9864        0       0           0   2020       1
# 2020-01-05 2020-01-05  10435        0       0           0   2020       1
# ...               ...    ...      ...     ...         ...    ...     ...
# 2022-12-27 2022-12-27  17042        0       0           0   2022      12
# 2022-12-28 2022-12-28  16195        0       0           0   2022      12
# 2022-12-29 2022-12-29  14966        0       0           0   2022      12
# 2022-12-30 2022-12-30  13070        0       0           0   2022      12
# 2022-12-31 2022-12-31   9991        0       0           0   2022      12
#
#             days  dayoftheweek  days_since_years  days_since_months  \
# ds
# 2020-01-01     1             2          0.693147           0.693147
# 2020-01-02     2             3          0.693147           0.693147
# 2020-01-03     3             4          0.693147           0.693147
# 2020-01-04     4             5          0.693147           0.693147
# 2020-01-05     5             6          0.693147           0.693147
# ...          ...           ...               ...                ...
# 2022-12-27    27             1          1.386294           2.564949
# 2022-12-28    28             2          1.386294           2.564949
# 2022-12-29    29             3          1.386294           2.564949
# 2022-12-30    30             4          1.386294           2.564949
# 2022-12-31    31             5          1.386294           2.564949
#
#             days_since_days  days_since_dow
# ds
# 2020-01-01         0.693147        1.098612
# 2020-01-02         1.098612        1.386294
# 2020-01-03         1.386294        1.609438
# 2020-01-04         1.609438        1.791759
# 2020-01-05         1.791759        1.945910
# ...                     ...             ...
# 2022-12-27         6.996681        0.693147
# 2022-12-28         6.997596        1.098612
# 2022-12-29         6.998510        1.386294
# 2022-12-30         6.999422        1.609438
# 2022-12-31         7.000334        1.791759
#
# [1088 rows x 13 columns]

# %%
#Разделяем данные на тренировочный и тестовый наборы
train = data[:731]
test = data[731:]

# %%
#обучение модели на тестовых данных
model = MyLineReg(n_iter = 3000, learning_rate = 0.01, metric = 'mape', l1_coef = 0, l2_coef = 0)
model.fit(train[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']], train['y'])
#прогнозирование на тестовых данных
y_pred = model.predict(test[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']])
mape = model.get_best_score()
mape
# Out:
# 8.3411365906

# %%
#построение графика фактических и прогнозируемых значений для тестового периода
plt.figure(figsize=(20, 10))
plt.plot(data.query('ds >= "2022-01-01"')['ds'], data.query('ds >= "2022-01-01"')['y'], label='Actual')
plt.plot(data.query('ds >= "2022-01-01"')['ds'], y_pred, label='Forecast')

# %%
#функция для обучения модели с разными параметрами
def training(params):
    model = MyLineReg(**params, metric = 'mape')
    model.fit(data[['ramadan', 'corona', 'is_holiday','days_since_years', 'days_since_months','days_since_days']], data['y'])
    return model.get_best_score()
param_grid = {
    'n_iter': np.linspace(1000, 5000, num=20, dtype=int),
    'learning_rate': np.arange(0.005, 0.1, 0.01)
}
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
all_params
# Out:
# [{'n_iter': 1000, 'learning_rate': 0.005},
#  {'n_iter': 1000, 'learning_rate': 0.015},
#  {'n_iter': 1000, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 1000, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 1000, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 1000, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 1000, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 1000, 'learning_rate': 0.075},
#  {'n_iter': 1000, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 1000, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 1210, 'learning_rate': 0.005},
#  {'n_iter': 1210, 'learning_rate': 0.015},
#  {'n_iter': 1210, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 1210, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 1210, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 1210, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 1210, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 1210, 'learning_rate': 0.075},
#  {'n_iter': 1210, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 1210, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 1421, 'learning_rate': 0.005},
#  {'n_iter': 1421, 'learning_rate': 0.015},
#  {'n_iter': 1421, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 1421, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 1421, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 1421, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 1421, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 1421, 'learning_rate': 0.075},
#  {'n_iter': 1421, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 1421, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 1631, 'learning_rate': 0.005},
#  {'n_iter': 1631, 'learning_rate': 0.015},
#  {'n_iter': 1631, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 1631, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 1631, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 1631, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 1631, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 1631, 'learning_rate': 0.075},
#  {'n_iter': 1631, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 1631, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 1842, 'learning_rate': 0.005},
#  {'n_iter': 1842, 'learning_rate': 0.015},
#  {'n_iter': 1842, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 1842, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 1842, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 1842, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 1842, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 1842, 'learning_rate': 0.075},
#  {'n_iter': 1842, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 1842, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 2052, 'learning_rate': 0.005},
#  {'n_iter': 2052, 'learning_rate': 0.015},
#  {'n_iter': 2052, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 2052, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 2052, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 2052, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 2052, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 2052, 'learning_rate': 0.075},
#  {'n_iter': 2052, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 2052, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 2263, 'learning_rate': 0.005},
#  {'n_iter': 2263, 'learning_rate': 0.015},
#  {'n_iter': 2263, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 2263, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 2263, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 2263, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 2263, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 2263, 'learning_rate': 0.075},
#  {'n_iter': 2263, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 2263, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 2473, 'learning_rate': 0.005},
#  {'n_iter': 2473, 'learning_rate': 0.015},
#  {'n_iter': 2473, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 2473, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 2473, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 2473, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 2473, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 2473, 'learning_rate': 0.075},
#  {'n_iter': 2473, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 2473, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 2684, 'learning_rate': 0.005},
#  {'n_iter': 2684, 'learning_rate': 0.015},
#  {'n_iter': 2684, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 2684, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 2684, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 2684, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 2684, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 2684, 'learning_rate': 0.075},
#  {'n_iter': 2684, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 2684, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 2894, 'learning_rate': 0.005},
#  {'n_iter': 2894, 'learning_rate': 0.015},
#  {'n_iter': 2894, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 2894, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 2894, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 2894, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 2894, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 2894, 'learning_rate': 0.075},
#  {'n_iter': 2894, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 2894, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 3105, 'learning_rate': 0.005},
#  {'n_iter': 3105, 'learning_rate': 0.015},
#  {'n_iter': 3105, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 3105, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 3105, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 3105, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 3105, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 3105, 'learning_rate': 0.075},
#  {'n_iter': 3105, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 3105, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 3315, 'learning_rate': 0.005},
#  {'n_iter': 3315, 'learning_rate': 0.015},
#  {'n_iter': 3315, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 3315, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 3315, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 3315, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 3315, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 3315, 'learning_rate': 0.075},
#  {'n_iter': 3315, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 3315, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 3526, 'learning_rate': 0.005},
#  {'n_iter': 3526, 'learning_rate': 0.015},
#  {'n_iter': 3526, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 3526, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 3526, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 3526, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 3526, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 3526, 'learning_rate': 0.075},
#  {'n_iter': 3526, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 3526, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 3736, 'learning_rate': 0.005},
#  {'n_iter': 3736, 'learning_rate': 0.015},
#  {'n_iter': 3736, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 3736, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 3736, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 3736, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 3736, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 3736, 'learning_rate': 0.075},
#  {'n_iter': 3736, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 3736, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 3947, 'learning_rate': 0.005},
#  {'n_iter': 3947, 'learning_rate': 0.015},
#  {'n_iter': 3947, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 3947, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 3947, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 3947, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 3947, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 3947, 'learning_rate': 0.075},
#  {'n_iter': 3947, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 3947, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 4157, 'learning_rate': 0.005},
#  {'n_iter': 4157, 'learning_rate': 0.015},
#  {'n_iter': 4157, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 4157, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 4157, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 4157, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 4157, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 4157, 'learning_rate': 0.075},
#  {'n_iter': 4157, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 4157, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 4368, 'learning_rate': 0.005},
#  {'n_iter': 4368, 'learning_rate': 0.015},
#  {'n_iter': 4368, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 4368, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 4368, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 4368, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 4368, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 4368, 'learning_rate': 0.075},
#  {'n_iter': 4368, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 4368, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 4578, 'learning_rate': 0.005},
#  {'n_iter': 4578, 'learning_rate': 0.015},
#  {'n_iter': 4578, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 4578, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 4578, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 4578, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 4578, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 4578, 'learning_rate': 0.075},
#  {'n_iter': 4578, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 4578, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 4789, 'learning_rate': 0.005},
#  {'n_iter': 4789, 'learning_rate': 0.015},
#  {'n_iter': 4789, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 4789, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 4789, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 4789, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 4789, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 4789, 'learning_rate': 0.075},
#  {'n_iter': 4789, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 4789, 'learning_rate': 0.09499999999999999},
#  {'n_iter': 5000, 'learning_rate': 0.005},
#  {'n_iter': 5000, 'learning_rate': 0.015},
#  {'n_iter': 5000, 'learning_rate': 0.024999999999999998},
#  {'n_iter': 5000, 'learning_rate': 0.034999999999999996},
#  {'n_iter': 5000, 'learning_rate': 0.04499999999999999},
#  {'n_iter': 5000, 'learning_rate': 0.054999999999999986},
#  {'n_iter': 5000, 'learning_rate': 0.06499999999999999},
#  {'n_iter': 5000, 'learning_rate': 0.075},
#  {'n_iter': 5000, 'learning_rate': 0.08499999999999999},
#  {'n_iter': 5000, 'learning_rate': 0.09499999999999999}]

# %%
#поиск оптимальных параметров
mapes = []
start_time = time()
for params in all_params:
    mapes.append(training(params))
best_params = all_params[np.argmin(mapes)]
print(best_params)
'MAPE', min(mapes)
# Out:
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\kolesa_exam_python\Models\LinearRegression.py:102: RuntimeWarning: overflow encountered in multiply
#   return round(self.best_score, 10)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ...
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\kondr\anaconda3\Lib\site-packages\numpy\core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# {'n_iter': 1000, 'learning_rate': 0.04499999999999999}
# ('MAPE', 8.0886646922)

# %%
model = MyLineReg(n_iter = 3000, learning_rate = 0.01, metric = 'mape')
model.fit(train[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']], train['y'])
#прогнозирование на тестовых данных
y_pred = model.predict(test[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']])
mape = model.get_best_score()
mape
# Out:
# 8.3411365906

# %%
model = MyLineReg(n_iter = 3000, learning_rate = 0.01, metric = 'mape')
model.fit(data[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']], data['y'])
start_date = '2023-01-01'
end_date = '2023-12-31'
dates_2023 = pd.date_range(start=start_date, end=end_date)
ds_2023 = pd.DataFrame({'ds': dates_2023})
ds_2023['ds'] = pd.to_datetime(ds_2023['ds'])
#добавление столбца для указания, является ли дата праздничной
ds_2023['is_holiday'] = ds_2023['ds'].isin(df_holidays['ds'])
ds_2023['is_holiday'] = ds_2023['is_holiday'].apply(int)
ds_2023['ramadan'] = ds_2023['ds'].apply(ramadan).apply(int)
ds_2023['corona'] = ds_2023['ds'].apply(corona).apply(int)
#извлечение информации о годе, месяце, дне и дне недели из столбца 'ds'
reference_date = pd.Timestamp('2019-12-30')
ds_2023['years'] = (ds_2023['ds']).dt.year
ds_2023['months'] = (ds_2023['ds'] ).dt.month
ds_2023['days'] = (ds_2023['ds']).dt.day
ds_2023['dayoftheweek'] = (ds_2023['ds']).dt.dayofweek
#расчет логарифма дней с определенных точек отсчета
ds_2023['days_since_years'] = np.log((ds_2023['ds']).dt.year - 2018)
ds_2023['days_since_months'] = np.log((ds_2023['ds'] ).dt.month+1)
ds_2023['days_since_days'] = np.log((ds_2023['ds'] - reference_date).dt.days)
ds_2023['days_since_dow'] = np.log((ds_2023['ds']).dt.dayofweek+1)
model.predict(ds_2023[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']])
# Out:
# 0      14744.953571
# 1      15823.693040
# 2      15440.459740
# 3      15216.594466
# 4      15057.977378
# 5      14935.112344
# 6      14834.860998
# 7      14750.214937
# 8      15828.949633
# 9      15445.711570
# 10     15221.841540
# 11     15063.219706
# 12     14940.349934
# 13     14840.093859
# 14     14755.443077
# 15     15834.173061
# 16     15450.930295
# 17     15227.055570
# 18     15068.429049
# 19     14945.554598
# 20     14845.293853
# 21     14760.638410
# 22     15839.363741
# 23     15456.116329
# 24     15232.236967
# 25     15073.605819
# 26     14950.726748
# 27     14850.461391
# 28     14765.801344
# 29     15844.522079
# 30     15461.270080
# 31     15823.842176
# 32     15665.206456
# 33     15542.322822
# 34     15442.052910
# 35     15357.388317
# 36     16436.104513
# 37     16052.847984
# 38     15828.959521
# 39     15670.319286
# 40     15547.431146
# 41     15447.156735
# 42     15362.487651
# 43     16441.199364
# 44     16057.938360
# 45     15834.045429
# 46     15675.400735
# 47     15552.508143
# 48     15452.229289
# 49     15367.555769
# 50     16446.263054
# 51     16062.997629
# 52     15839.100285
# 53     15680.451186
# 54     15557.554197
# 55     15457.270952
# 56     15372.593050
# 57     16451.295961
# 58     16068.026169
# 59     16260.221645
# 60     16101.568194
# 61     15978.666861
# 62     15878.379280
# 63     15793.697048
# 64     16872.395637
# 65     16489.121530
# 66     16265.215521
# 67     16106.557770
# 68     15983.652144
# 69     15883.360278
# 70     15798.673769
# 71     16877.368088
# 72     16494.089719
# 73     16270.179454
# 74     16111.517455
# 75     15988.607588
# 76     15888.311489
# 77     15803.620753
# 78     16882.310853
# 79     16499.028272
# 80     16275.113802
# 81     16332.481102
# 82     16209.567044
# 83     16109.266761
# 84     16024.571849
# 85     17103.257780
# 86     16719.971036
# 87     16496.052411
# 88     16337.382067
# 89     16214.463868
# 90     16436.909498
# 91     16352.210459
# 92     17430.892269
# 93     17047.601413
# 94     16823.678681
# 95     16665.004237
# 96     16542.081946
# 97     16441.773444
# 98     16357.070326
# 99     17435.748064
# 100    17052.453142
# 101    16828.526353
# 102    16669.847857
# 103    16546.921521
# 104    16446.608981
# 105    16361.901832
# 106    17440.575545
# 107    17057.276606
# 108    16833.345804
# 109    16674.663305
# 110    16551.732971
# 111    16451.416439
# 112    16366.705305
# 113    17445.375041
# 114    16846.038633
# 115    16622.103867
# 116    16463.417409
# 117    16340.483124
# 118    16240.162646
# 119    16155.447574
# 120    17497.819366
# 121    17114.512529
# 122    16890.573844
# 123    16731.883473
# 124    16608.945281
# 125    16508.620903
# 126    16423.901937
# 127    17502.563853
# 128    17119.253135
# 129    16895.310575
# 130    16736.616336
# 131    16613.674282
# 132    16513.346048
# 133    16428.623233
# 134    17507.281305
# 135    17123.966751
# 136    16900.020360
# 137    16741.322296
# 138    16618.376424
# 139    16518.044378
# 140    16433.317757
# 141    17511.972030
# 142    17128.653681
# 143    16904.703503
# 144    16746.001658
# 145    16623.052011
# 146    16522.716196
# 147    16437.985812
# 148    17516.636327
# 149    17133.314228
# 150    16909.360305
# 151    16973.614958
# 152    16850.661578
# 153    16750.322036
# 154    16665.587931
# 155    17744.234732
# 156    17360.908923
# 157    17136.951297
# 158    16978.242016
# 159    16855.284944
# 160    16754.941717
# 161    16670.203932
# 162    17748.847059
# 163    17365.517583
# 164    17141.556295
# 165    16982.843357
# 166    16859.882635
# 167    16759.535763
# 168    16674.794340
# 169    17753.433834
# 170    17370.100730
# 171    17146.135820
# 172    16987.419266
# 173    16864.454934
# 174    16764.104458
# 175    16679.359435
# 176    17757.995336
# 177    17374.658645
# 178    17150.690153
# 179    16991.970024
# 180    16869.002121
# 181    16961.785022
# 182    16877.036440
# 183    17955.668787
# 184    17572.328547
# 185    17348.356513
# 186    17189.632846
# 187    17066.661411
# 188    16966.303844
# 189    16881.551741
# 190    17960.180573
# 191    17576.836823
# 192    17352.861284
# 193    17194.134119
# 194    17071.159190
# 195    16970.798135
# 196    16886.042550
# 197    17964.667904
# 198    17581.320683
# 199    17357.341678
# 200    17198.611051
# 201    17075.632667
# 202    16975.268161
# 203    16890.509130
# 204    17969.131045
# 205    17585.780390
# 206    17361.797955
# 207    17203.063904
# 208    17080.082101
# 209    16979.714182
# 210    16894.951743
# 211    17973.570255
# 212    17760.575058
# 213    17536.589231
# 214    17377.851793
# 215    17254.866608
# 216    17154.495312
# 217    17069.729501
# 218    18148.344645
# 219    17764.987231
# 220    17540.998047
# 221    17382.257257
# 222    17259.268726
# 223    17158.894088
# 224    17074.124941
# 225    18152.736755
# 226    17769.376014
# 227    17545.383509
# 228    17386.639403
# 229    17263.647561
# 230    17163.269617
# 231    17078.497169
# 232    18157.105687
# 233    17773.741654
# 234    17549.745863
# 235    17390.998476
# 236    17268.003358
# 237    17167.622143
# 238    17082.846428
# 239    18161.451684
# 240    17778.084395
# 241    17554.085353
# 242    17395.334718
# 243    17424.727548
# 244    17324.343096
# 245    17239.564149
# 246    18318.166177
# 247    17934.795666
# 248    17710.793405
# 249    17552.039558
# 250    17429.037989
# 251    17328.650333
# 252    17243.868187
# 253    18322.467022
# 254    17939.093321
# 255    17715.087875
# 256    17556.330848
# 257    17433.326104
# 258    17332.935278
# 259    17248.149966
# 260    18326.745639
# 261    17943.368782
# 262    17719.360184
# 263    17560.600010
# 264    17437.592123
# 265    17337.198159
# 266    17252.409714
# 267    18331.002259
# 268    17947.622277
# 269    17723.610560
# 270    17564.847271
# 271    17441.836273
# 272    17341.439203
# 273    17394.502257
# 274    18473.091705
# 275    18089.708631
# 276    17865.693826
# 277    17706.927454
# 278    17583.913378
# 279    17483.513233
# 280    17398.718617
# 281    18477.305000
# 282    18093.918865
# 283    17869.901004
# 284    17711.131579
# 285    17588.114456
# 286    17487.711268
# 287    17402.913613
# 288    18481.496961
# 289    18098.107796
# 290    17874.086910
# 291    17715.314464
# 292    17592.294323
# 293    17491.888124
# 294    17407.087460
# 295    18485.667805
# 296    18102.275640
# 297    17878.251758
# 298    17719.476322
# 299    17596.453194
# 300    17496.044012
# 301    17411.240371
# 302    18489.817741
# 303    18106.422607
# 304    18008.247150
# 305    17849.468752
# 306    17726.442668
# 307    17626.030533
# 308    17541.223943
# 309    18619.798370
# 310    18236.400296
# 311    18012.370513
# 312    17853.589183
# 313    17730.560172
# 314    17630.145113
# 315    17545.335605
# 316    18623.907116
# 317    18240.506131
# 318    18016.473441
# 319    17857.689209
# 320    17734.657299
# 321    17634.239346
# 322    17549.426947
# 323    18627.995572
# 324    18244.591705
# 325    18020.556137
# 326    17861.769030
# 327    17738.734250
# 328    17638.313431
# 329    17553.498170
# 330    18632.063937
# 331    18248.657216
# 332    18024.618798
# 333    17865.828845
# 334    17858.563279
# 335    17758.139622
# 336    17673.321527
# 337    18751.884463
# 338    18368.474916
# 339    18144.433676
# 340    17985.640905
# 341    17862.600469
# 342    17762.174002
# 343    17677.353100
# 344    18755.913234
# 345    18372.500888
# 346    18148.456853
# 347    17989.661291
# 348    17866.618067
# 349    17766.188817
# 350    17681.365136
# 351    18759.922494
# 352    18376.507376
# 353    18152.460573
# 354    17993.662248
# 355    17870.616264
# 356    17770.184257
# 357    17685.357823
# 358    18763.912433
# 359    18380.494570
# 360    18156.445026
# 361    17997.643962
# 362    17874.595245
# 363    17774.160508
# 364    17689.331348
# dtype: float64

# %%
#построение прогнозируемого графика
yhat = pd.DataFrame(model.predict(ds_2023[['days_since_years', 'days_since_months','days_since_days','days_since_dow', 'corona', 'ramadan']]), columns=['yhat'])
ds_2023['y_hat'] = yhat
plt.figure(figsize=(20, 10))
plt.plot(ds_2023['ds'], ds_2023['y_hat'])

# %%
#выгрузка данных
ds_2023[['ds', 'y_hat']].to_excel('линейная_прогноз.xlsx', index=False)
